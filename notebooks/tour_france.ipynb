# %%
pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (4.13.4)
# Requirement already satisfied: pandas in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (2.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from beautifulsoup4) (4.14.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\victo\miniconda3\envs\cycling_points_uci_vfg\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

BASE_URL = "https://www.procyclingstats.com"
RACE_BASE = "/race/tour-de-france/"
HEADERS = {"User-Agent": "Mozilla/5.0"}

# Script para extraer resultados del Tour de France 2015-2024
anios = [f"{i}/" for i in range(2017, 2025)]  # Años de 2015 a 2024

# Asumimos 21 etapas
etapas = [f"stage-{i}" for i in range(1, 22)]


all_etapas = []

#recorrer cada año y cada etapa
for anio in anios:
    print(f"Procesando año: {anio.strip('/')}")

    for etapa in etapas:
        url = BASE_URL + RACE_BASE + anio + etapa
        print(f"Procesando: {url}")
        
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Error al acceder a la etapa {etapa}: {response.status_code}")
            continue
        
        soup = BeautifulSoup(response.text, "html.parser")
        table = soup.find("table", {"class": "results"})

        if not table:
            print(f"No se encontró tabla en {etapa}")
            continue

        headers = [th.text.strip() for th in table.find_all("th")]
        rows = []
        for tr in table.find_all("tr")[1:]:
            cols = [td.text.strip() for td in tr.find_all("td")]
            if cols:
                rows.append(cols)

        df_etapa = pd.DataFrame(rows, columns=headers)
        df_etapa["Etapa"] = etapa
        df_etapa["Anio"] = anio.strip("/")
        all_etapas.append(df_etapa)

        # Esperar para evitar bloqueo
        time.sleep(3)

# Unir todas las etapas
df_total = pd.concat(all_etapas, ignore_index=True)
print(df_total)
# Guardar como CSV
df_total.to_csv("tour_france_2017_2024_etapas.csv", index=False)
print("✅ Archivo CSV generado: tour_france_2017_2024_etapas.csv")
# Out:
# Procesando año: 2017
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-1
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-2
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-3
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-4
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-5
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-6
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-7
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-8
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-9
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-10
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-11
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-12
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-13
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-14
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-15
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-16
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-17
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-18
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-19
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-20
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2017/stage-21
# Procesando año: 2018
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-1
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-2
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-3
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-4
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-5
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-6
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-7
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-8
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-9
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-10
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-11
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-12
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-13
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-14
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-15
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-16
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-17
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-18
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-19
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-20
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2018/stage-21
# Procesando año: 2019
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-1
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-2
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-3
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-4
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-5
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-6
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-7
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-8
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-9
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-10
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-11
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-12
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-13
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-14
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-15
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-16
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-17
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-18
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-19
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-20
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2019/stage-21
# Procesando año: 2020
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-1
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-2
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-3
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-4
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-5
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-6
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-7
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-8
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-9
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-10
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-11
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-12
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-13
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-14
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-15
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-16
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-17
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-18
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-19
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-20
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2020/stage-21
# Procesando año: 2021
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-1
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-2
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-3
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-4
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-5
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-6
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-7
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-8
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-9
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-10
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-11
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-12
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-13
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-14
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-15
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-16
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-17
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-18
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-19
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-20
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2021/stage-21
# Procesando año: 2022
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-1
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-2
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-3
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-4
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-5
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-6
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-7
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-8
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-9
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-10
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-11
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-12
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-13
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-14
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-15
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-16
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-17
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-18
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-19
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-20
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2022/stage-21
# Procesando año: 2023
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-1
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-2
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-3
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-4
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-5
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-6
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-7
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-8
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-9
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-10
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-11
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-12
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-13
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-14
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-15
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-16
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-17
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-18
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-19
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-20
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2023/stage-21
# Procesando año: 2024
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-1
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-2
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-3
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-4
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-5
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-6
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-7
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-8
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-9
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-10
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-11
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-12
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-13
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-14
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-15
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-16
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-17
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-18
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-19
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-20
# Procesando: https://www.procyclingstats.com/race/tour-de-france/2024/stage-21
#        Rnk   GC   Timelag  BIB H2H Specialty  \
# 0        1    1     +0:00    9            GC
# 1        2    2     +0:05   44            TT
# 2        3    3     +0:07    3            TT
# 3        4    4     +0:08  121            TT
# 4        5    5     +0:10  108       Classic
# ...    ...  ...       ...  ...  ..       ...
# 27880  137  132  +5:40:58  213       Classic
# 27881  138  133  +5:46:24  208            TT
# 27882  139  111  +5:08:28   62         Hills
# 27883  140   44  +2:55:47   16       Climber
# 27884  141  135  +5:57:41   23        Sprint
#
#                                     Rider Age                  Team  UCI  Pnt  \
# 0                 THOMAS Geraint Team Sky  31              Team Sky  120  100
# 1             KÜNG Stefan BMC Racing Team  23       BMC Racing Team   50   70
# 2                KIRYIENKA Vasil Team Sky  36              Team Sky   25   50
# 3        MARTIN Tony Team Katusha Alpecin  32  Team Katusha Alpecin   15   40
# 4        TRENTIN Matteo Quick-Step Floors  27     Quick-Step Floors    5   32
# ...                                   ...  ..                   ...  ...  ...
# 27880        DUJARDIN Sandy TotalEnergies  27         TotalEnergies
# 27881    WÆRENSKJOLD Søren Uno-X Mobility  24        Uno-X Mobility
# 27882   ARNDT Nikias Bahrain - Victorious  32  Bahrain - Victorious
# 27883        SOLER Marc UAE Team Emirates  30     UAE Team Emirates
# 27884  GROENEWEGEN Dylan Team Jayco AlUla  31      Team Jayco AlUla
#
#               Time     Avg     Etapa  Anio Prev   ▼▲ Time won/lost
# 0          0:16:04  52.282   stage-1  2017  NaN  NaN           NaN
# 1         0:050:05  52.012   stage-1  2017  NaN  NaN           NaN
# 2         0:070:07  51.905   stage-1  2017  NaN  NaN           NaN
# 3         0:080:08  51.852   stage-1  2017  NaN  NaN           NaN
# 4         0:100:10  51.745   stage-1  2017  NaN  NaN           NaN
# ...   ..       ...     ...       ...   ...  ...  ...           ...
# 27880      9.35,22  36.761  stage-21  2024  NaN  NaN           NaN
# 27881      9.39,38  36.715  stage-21  2024  NaN  NaN           NaN
# 27882         9.40  36.708  stage-21  2024  NaN  NaN           NaN
# 27883      9.45,79  36.644  stage-21  2024  NaN  NaN           NaN
# 27884     10.40,19  36.052  stage-21  2024  NaN  NaN           NaN
#
# [27885 rows x 19 columns]
# ✅ Archivo CSV generado: tour_france_2017_2024_etapas.csv
