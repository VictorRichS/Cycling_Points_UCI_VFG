# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

BASE_URL = "https://www.procyclingstats.com"
RACE_BASE = "/race/giro-d-italia/"
HEADERS = {"User-Agent": "Mozilla/5.0"}

# Script para extraer resultados de la Vuelta a España 2015-2024
anios = [f"{i}/" for i in range(2015, 2025)]  # Años de 2015 a 2024

# Asumimos 21 etapas
etapas = [f"stage-{i}" for i in range(1, 22)]


all_etapas = []

#recorrer cada año y cada etapa
for anio in anios:
    print(f"Procesando año: {anio.strip('/')}")

    for etapa in etapas:
        url = BASE_URL + RACE_BASE + anio + etapa
        print(f"Procesando: {url}")
        
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Error al acceder a la etapa {etapa}: {response.status_code}")
            continue
        
        soup = BeautifulSoup(response.text, "html.parser")
        table = soup.find("table", {"class": "results"})

        if not table:
            print(f"No se encontró tabla en {etapa}")
            continue

        headers = [th.text.strip() for th in table.find_all("th")]
        rows = []
        for tr in table.find_all("tr")[1:]:
            cols = [td.text.strip() for td in tr.find_all("td")]
            if cols:
                rows.append(cols)

        df_etapa = pd.DataFrame(rows, columns=headers)
        df_etapa["Etapa"] = etapa
        df_etapa["Año"] = anio.strip("/")
        all_etapas.append(df_etapa)

        # Esperar para evitar bloqueo
        time.sleep(3)

# Unir todas las etapas
df_total = pd.concat(all_etapas, ignore_index=True)
print(df_total)
# Guardar como CSV
df_total.to_csv("giro_d_italia_2015_2024_etapas.csv", index=False)
print("✅ Archivo CSV generado: giro_d_italia_2015_2024_etapas.csv")
# Out:
# Procesando año: 2015
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2015/stage-21
# Procesando año: 2016
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2016/stage-21
# Procesando año: 2017
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2017/stage-21
# Procesando año: 2018
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2018/stage-21
# Procesando año: 2019
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2019/stage-21
# Procesando año: 2020
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2020/stage-21
# Procesando año: 2021
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2021/stage-21
# Procesando año: 2022
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2022/stage-21
# Procesando año: 2023
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2023/stage-21
# Procesando año: 2024
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-1
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-2
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-3
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-4
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-5
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-6
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-7
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-8
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-9
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-10
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-11
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-12
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-13
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-14
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-15
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-16
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-17
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-18
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-19
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-20
# Procesando: https://www.procyclingstats.com/race/giro-d-italia/2024/stage-21
#        Rnk  BIB H2H Specialty                                  Rider Age  \
# 0        1  136       Classic          GERRANS Simon Orica GreenEDGE  34
# 1        2  131       Classic       MATTHEWS Michael Orica GreenEDGE  24
# 2        3  137            TT        HEPBURN Michael Orica GreenEDGE  23
# 3        4  139            GC         WEENING Pieter Orica GreenEDGE  34
# 4        5  134       Classic           CLARKE Simon Orica GreenEDGE  28
# ...    ...  ...  ..       ...                                    ...  ..
# 35056  138  138       Climber    VANSEVENANT Mauri Soudal Quick-Step  24
# 35057  139   15       Classic    JANSSENS Jimmy Alpecin - Deceuninck  34
# 35058  140   94        Sprint    DE POOTER Dries Intermarché - Wanty  21
# 35059  141  188            GC   STORK Florian Tudor Pro Cycling Team  27
# 35060  142  104       Classic  HOFSTETTER Hugo Israel - Premier Tech  30
#
#                          Team           Time Time won/lost     Etapa   Año  \
# 0             Orica GreenEDGE        0:19:26            ..   stage-1  2015
# 1             Orica GreenEDGE         ,,0:00            ..   stage-1  2015
# 2             Orica GreenEDGE         ,,0:00            ..   stage-1  2015
# 3             Orica GreenEDGE         ,,0:00            ..   stage-1  2015
# 4             Orica GreenEDGE         ,,0:00            ..   stage-1  2015
# ...                       ... ..         ...           ...       ...   ...
# 35056       Soudal Quick-Step       6:156:15           NaN  stage-21  2024
# 35057    Alpecin - Deceuninck         ,,6:15           NaN  stage-21  2024
# 35058     Intermarché - Wanty         ,,6:15           NaN  stage-21  2024
# 35059  Tudor Pro Cycling Team         ,,6:15           NaN  stage-21  2024
# 35060   Israel - Premier Tech     15:1015:10           NaN  stage-21  2024
#
#         GC   Timelag  UCI  Pnt  Avg
# 0      NaN       NaN  NaN  NaN  NaN
# 1      NaN       NaN  NaN  NaN  NaN
# 2      NaN       NaN  NaN  NaN  NaN
# 3      NaN       NaN  NaN  NaN  NaN
# 4      NaN       NaN  NaN  NaN  NaN
# ...    ...       ...  ...  ...  ...
# 35056   30  +1:47:43            NaN
# 35057   84  +4:13:19            NaN
# 35058  106  +4:43:53            NaN
# 35059   74  +3:54:30            NaN
# 35060  126  +5:25:50            NaN
#
# [35061 rows x 17 columns]
# ✅ Archivo CSV generado: giro_d_italia_2015_2024_etapas.csv
